# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from pyxlsb import open_workbook as open_xlsb

# %%
Years = ['2000','2001','2002','2003','2004','2005','2006','2007','2008','2009','2010','2011','2012','2013','2014']

Sector = {'Agricultural' : ['Crop and animal production, hunting and related service activities', 'Forestry and logging', 'Fishing and aquaculture'],
          'Manufacturing' : ['Manufacture of food products, beverages and tobacco products',
                             'Manufacture of textiles, wearing apparel and leather products',
                             'Manufacture of wood and of products of wood and cork, except furniture; manufacture of articles of straw and plaiting materials',
                             'Manufacture of paper and paper products',
                             'Manufacture of coke and refined petroleum products ',
                             'Manufacture of chemicals and chemical products ',
                             'Manufacture of basic pharmaceutical products and pharmaceutical preparations',
                             'Manufacture of rubber and plastic products',
                             'Manufacture of other non-metallic mineral products',
                             'Manufacture of basic metals',
                             'Manufacture of fabricated metal products, except machinery and equipment',
                             'Manufacture of computer, electronic and optical products',
                             'Manufacture of electrical equipment',
                             'Manufacture of machinery and equipment n.e.c.',
                             'Manufacture of furniture; other manufacturing'],
         'Mining' : ['Mining and quarrying'],

         'Power' : ['Electricity, gas, steam and air conditioning supply'],

         'Water' : ['Water collection, treatment and supply',
                    'Sewerage; waste collection, treatment and disposal activities; materials recovery; remediation activities and other waste management services ',
                    'Construction'],

         'Retail' : ['Wholesale trade, except of motor vehicles and motorcycles',
                     'Retail trade, except of motor vehicles and motorcycles'],

         'Transportation' : ['Land transport and transport via pipelines',
                             'Water transport',
                             'Air transport',
                             'Warehousing and support activities for transportation'],

        'Food' : ['Accommodation and food service activities'],

        'Entertainment' : ['Printing and reproduction of recorded media','Publishing activities', 'Advertising and market research',
                           'Motion picture, video and television programme production, sound recording and music publishing activities; programming and broadcasting activities'],

        'IT' : ['Telecommunications',
                'Computer programming, consultancy and related activities; information service activities'],

        'Finance' : ['Financial service activities, except insurance and pension funding',
                     'Insurance, reinsurance and pension funding, except compulsory social security',
                     'Activities auxiliary to financial services and insurance activities',
                     'Real estate activities',
                     'Legal and accounting activities; activities of head offices; management consultancy activities'],

        'Education' : ['Architectural and engineering activities; technical testing and analysis',
                       'Scientific research and development',
                       'Other professional, scientific and technical activities; veterinary activities',
                       'Administrative and support service activities',
                         'Public administration and defence; compulsory social security',
                         'Education',
                         'Human health and social work activities',
                         'Other service activities',
                         'Activities of households as employers; undifferentiated goods- and services-producing activities of households for own use',
                         'Activities of extraterritorial organizations and bodies'],

        'Automobile' : ['Repair and installation of machinery and equipment', 'Manufacture of motor vehicles, trailers and semi-trailers',
                         'Manufacture of other transport equipment', 'Wholesale and retail trade and repair of motor vehicles and motorcycles']}

for year in Years:
    df = []

    with open_xlsb('WIOT' + year +'_Nov16_ROW.xlsb') as wb:
        with wb.get_sheet(1) as sheet:
            for row in sheet.rows():
                df.append([item.v for item in row])

    df = pd.DataFrame(df[1:])
    industries = list(df.iloc[2].unique())
    industries.remove(None)
    industries.remove('(millions of US$)')
    industries.remove('Final consumption expenditure by households')
    industries.remove('Final consumption expenditure by non-profit organisations serving households (NPISH)')
    industries.remove('Final consumption expenditure by government')
    industries.remove('Gross fixed capital formation')
    industries.remove('Changes in inventories and valuables')
    industries.remove('Total output')
    
    countries = list(df.iloc[3].unique())
    countries.remove(None)
    countries.remove('TOT')
    matrix = df.values
    newMatrix = matrix[5:2469, 4:2468]
    
    Country_Sector = []
    for country in countries:
        for indutry in list(Sector):
            comb = country + '(' + indutry + ')'
            Country_Sector.append(comb)
            
    ind_con = []
    for country in countries:
        for indutry in industries:
            comb = country + '(' + indutry + ')'
            ind_con.append(comb)
    
    DataIndustry = pd.DataFrame(newMatrix, index = ind_con)
    DataIndustry.columns = ind_con
    
    SectorCountry = []
    for country in countries:
        for sec in list(Sector):
            SectorCountry.append(country + '(' + sec + ')')
            
    list1 = []
    for country1 in countries:
        for sec1 in list(Sector):
            list2 = []
            for country2 in countries:
                ind1 = []            
                for industry1 in Sector[sec1]:
                    s = country1 + '(' + industry1 + ')'
                    ind1.append(s)
                sub_data = DataIndustry.loc[ind1]
                for sec2 in list(Sector):
                    ind2 = []
                    for industry2 in Sector[sec2]:
                        s = country2 + '(' + industry2 + ')'
                        ind2.append(s)
                    total_sum = np.matrix(sub_data[ind2].values).sum()
                    list2.append(total_sum)
            list1.append(list2)
            
    TotalSectorWiseData = pd.DataFrame()
    for i in range(len(list1)):
        TotalSectorWiseData[SectorCountry[i]] = list1[i]
    TotalSectorWiseData.index = SectorCountry
    TotalSectorWiseData.to_csv('/home/adityachourasiya/Desktop/Working/SGSIS/FNA/SectorWise/TotalSectorWiseData' + year +'.csv')

# %%
df = []

with open_xlsb('WIOT2000_Nov16_ROW.xlsb') as wb:
    with wb.get_sheet(1) as sheet:
        for row in sheet.rows():
            df.append([item.v for item in row])

df = pd.DataFrame(df[1:])

matrix = df.values

# %%
industries = list(df.iloc[2].unique())
industries.remove(None)
industries.remove('(millions of US$)')
industries.remove('Final consumption expenditure by households')
industries.remove('Final consumption expenditure by non-profit organisations serving households (NPISH)')
industries.remove('Final consumption expenditure by government')
industries.remove('Gross fixed capital formation')
industries.remove('Changes in inventories and valuables')
industries.remove('Total output')
len(industries)
# Out:
# 56

# %%
industries
# Out:
# ['Crop and animal production, hunting and related service activities',
#  'Forestry and logging',
#  'Fishing and aquaculture',
#  'Mining and quarrying',
#  'Manufacture of food products, beverages and tobacco products',
#  'Manufacture of textiles, wearing apparel and leather products',
#  'Manufacture of wood and of products of wood and cork, except furniture; manufacture of articles of straw and plaiting materials',
#  'Manufacture of paper and paper products',
#  'Printing and reproduction of recorded media',
#  'Manufacture of coke and refined petroleum products ',
#  'Manufacture of chemicals and chemical products ',
#  'Manufacture of basic pharmaceutical products and pharmaceutical preparations',
#  'Manufacture of rubber and plastic products',
#  'Manufacture of other non-metallic mineral products',
#  'Manufacture of basic metals',
#  'Manufacture of fabricated metal products, except machinery and equipment',
#  'Manufacture of computer, electronic and optical products',
# ...

# %%
Agricultural = ['Crop and animal production, hunting and related service activities', 'Forestry and logging', 'Fishing and aquaculture']

Manufacturing = ['Manufacture of food products, beverages and tobacco products',
 'Manufacture of textiles, wearing apparel and leather products',
 'Manufacture of wood and of products of wood and cork, except furniture; manufacture of articles of straw and plaiting materials',
 'Manufacture of paper and paper products',
 'Manufacture of coke and refined petroleum products ',
 'Manufacture of chemicals and chemical products ',
 'Manufacture of basic pharmaceutical products and pharmaceutical preparations',
 'Manufacture of rubber and plastic products',
 'Manufacture of other non-metallic mineral products',
 'Manufacture of basic metals',
 'Manufacture of fabricated metal products, except machinery and equipment',
 'Manufacture of computer, electronic and optical products',
 'Manufacture of electrical equipment',
 'Manufacture of machinery and equipment n.e.c.',
 'Manufacture of furniture; other manufacturing']

Mining = ['Mining and quarrying']

Service = ['Repair and installation of machinery and equipment']

Power = ['Electricity, gas, steam and air conditioning supply']

Water = ['Water collection, treatment and supply',
 'Sewerage; waste collection, treatment and disposal activities; materials recovery; remediation activities and other waste management services ',
 'Construction']

Retail = ['Wholesale trade, except of motor vehicles and motorcycles',
 'Retail trade, except of motor vehicles and motorcycles']

Transportation = ['Land transport and transport via pipelines',
 'Water transport',
 'Air transport',
 'Warehousing and support activities for transportation']

Food = ['Accommodation and food service activities']

Entertainment = ['Printing and reproduction of recorded media','Publishing activities', 'Advertising and market research',
 'Motion picture, video and television programme production, sound recording and music publishing activities; programming and broadcasting activities']

IT = ['Telecommunications',
 'Computer programming, consultancy and related activities; information service activities']

Finance = ['Financial service activities, except insurance and pension funding',
 'Insurance, reinsurance and pension funding, except compulsory social security',
 'Activities auxiliary to financial services and insurance activities',
 'Real estate activities',
 'Legal and accounting activities; activities of head offices; management consultancy activities']

Education = ['Architectural and engineering activities; technical testing and analysis',
 'Scientific research and development',
 'Other professional, scientific and technical activities; veterinary activities',
 'Administrative and support service activities',
 'Public administration and defence; compulsory social security',
 'Education',
 'Human health and social work activities',
 'Other service activities',
 'Activities of households as employers; undifferentiated goods- and services-producing activities of households for own use',
 'Activities of extraterritorial organizations and bodies']

Automobile = ['Manufacture of motor vehicles, trailers and semi-trailers',
 'Manufacture of other transport equipment', 'Wholesale and retail trade and repair of motor vehicles and motorcycles']

# %%
countries = list(df.iloc[3].unique())
countries.remove(None)
countries.remove('TOT')
len(countries)
# Out:
# 44

# %%
matrix = df.values
newMatrix = matrix[5:2469, 4:2468]
newMatrix.shape
# Out:
# (2464, 2464)

# %%
Sector = {'Agricultural' : ['Crop and animal production, hunting and related service activities', 'Forestry and logging', 'Fishing and aquaculture'],
          'Manufacturing' : ['Manufacture of food products, beverages and tobacco products',
                             'Manufacture of textiles, wearing apparel and leather products',
                             'Manufacture of wood and of products of wood and cork, except furniture; manufacture of articles of straw and plaiting materials',
                             'Manufacture of paper and paper products',
                             'Manufacture of coke and refined petroleum products ',
                             'Manufacture of chemicals and chemical products ',
                             'Manufacture of basic pharmaceutical products and pharmaceutical preparations',
                             'Manufacture of rubber and plastic products',
                             'Manufacture of other non-metallic mineral products',
                             'Manufacture of basic metals',
                             'Manufacture of fabricated metal products, except machinery and equipment',
                             'Manufacture of computer, electronic and optical products',
                             'Manufacture of electrical equipment',
                             'Manufacture of machinery and equipment n.e.c.',
                             'Manufacture of furniture; other manufacturing'],
         'Mining' : ['Mining and quarrying'],

         'Service' : ['Repair and installation of machinery and equipment'],

         'Power' : ['Electricity, gas, steam and air conditioning supply'],

         'Water' : ['Water collection, treatment and supply',
                    'Sewerage; waste collection, treatment and disposal activities; materials recovery; remediation activities and other waste management services ',
                    'Construction'],

         'Retail' : ['Wholesale trade, except of motor vehicles and motorcycles',
                     'Retail trade, except of motor vehicles and motorcycles'],

         'Transportation' : ['Land transport and transport via pipelines',
                             'Water transport',
                             'Air transport',
                             'Warehousing and support activities for transportation'],

        'Food' : ['Accommodation and food service activities'],

        'Entertainment' : ['Printing and reproduction of recorded media','Publishing activities', 'Advertising and market research',
                           'Motion picture, video and television programme production, sound recording and music publishing activities; programming and broadcasting activities'],

        'IT' : ['Telecommunications',
                'Computer programming, consultancy and related activities; information service activities'],

        'Finance' : ['Financial service activities, except insurance and pension funding',
                     'Insurance, reinsurance and pension funding, except compulsory social security',
                     'Activities auxiliary to financial services and insurance activities',
                     'Real estate activities',
                     'Legal and accounting activities; activities of head offices; management consultancy activities'],

        'Education' : ['Architectural and engineering activities; technical testing and analysis',
                       'Scientific research and development',
                       'Other professional, scientific and technical activities; veterinary activities',
                       'Administrative and support service activities',
                         'Public administration and defence; compulsory social security',
                         'Education',
                         'Human health and social work activities',
                         'Other service activities',
                         'Activities of households as employers; undifferentiated goods- and services-producing activities of households for own use',
                         'Activities of extraterritorial organizations and bodies'],

        'Automobile' : ['Manufacture of motor vehicles, trailers and semi-trailers',
                         'Manufacture of other transport equipment', 'Wholesale and retail trade and repair of motor vehicles and motorcycles']}

# %%
list(Sector)
# Out:
# ['Agricultural',
#  'Manufacturing',
#  'Mining',
#  'Service',
#  'Power',
#  'Water',
#  'Retail',
#  'Transportation',
#  'Food',
#  'Entertainment',
#  'IT',
#  'Finance',
#  'Education',
#  'Automobile']

# %%
Country_Sector = []
for country in countries:
    for indutry in list(Sector):
        comb = country + '(' + indutry + ')'
        Country_Sector.append(comb)
len(Country_Sector)
# Out:
# 616

# %%
del df[0]

# %%
del df[3]

# %%
df = df.drop([0,1,4], axis=0)

# %%
newMatrix = matrix[5:2469, 4:2468]
newMatrix.shape
# Out:
# (2464, 2464)

# %%
ind_con = []
for country in countries:
    for indutry in industries:
        comb = country + '(' + indutry + ')'
        ind_con.append(comb)
len(ind_con)
# Out:
# 2464

# %%
DataIndustry = pd.DataFrame(newMatrix, index = ind_con)
DataIndustry.columns = ind_con
DataIndustry.shape
# Out:
# (2464, 2464)

# %%
DataIndustry.head()
# Out:
#                                                    AUS(Crop and animal production, hunting and related service activities)  \
# AUS(Crop and animal production, hunting and rel...                                            5876.83
# AUS(Forestry and logging)                                                                     78.0533
# AUS(Fishing and aquaculture)                                                                   10.916
# AUS(Mining and quarrying)                                                                     14.2061
# AUS(Manufacture of food products, beverages and...                                            820.497
#
#                                                    AUS(Forestry and logging)  \
# AUS(Crop and animal production, hunting and rel...                   187.068
# AUS(Forestry and logging)                                            41.4481
# AUS(Fishing and aquaculture)                                       0.0184803
# ...

# %%
SectorCountry = []
for country in countries:
    for sec in list(Sector):
        SectorCountry.append(country + '(' + sec + ')')
len(SectorCountry)
# Out:
# 616

# %%
sub_data = DataIndustry.loc[['AUS(Crop and animal production, hunting and related service activities)', 'AUS(Forestry and logging)']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-af5f18873fda> in <module>()
# ----> 1 sub_data = DataIndustry.loc[['AUS(Crop and animal production, hunting and related service activities)', 'AUS(Forestry and logging)']]
#
# NameError: name 'DataIndustry' is not defined

# %%
np.matrix(sub_data[['AUS(Crop and animal production, hunting and related service activities)','AUS(Forestry and logging)']].values).sum()
# Out:
# 6183.402590266322

# %%
list1 = []
for country1 in countries:
    for sec1 in list(Sector):
        list2 = []
        for country2 in countries:
            ind1 = []            
            for industry1 in Sector[sec1]:
                s = country1 + '(' + industry1 + ')'
                ind1.append(s)
            sub_data = DataIndustry.loc[ind1]
            for sec2 in list(Sector):
                ind2 = []
                for industry2 in Sector[sec2]:
                    s = country2 + '(' + industry2 + ')'
                    ind2.append(s)
                total_sum = np.matrix(sub_data[ind2].values).sum()
                list2.append(total_sum)
        list1.append(list2)

# %%
TotalSectorWiseData = pd.DataFrame()
for i in range(len(list1)):
    TotalSectorWiseData[SectorCountry[i]] = list1[i]
TotalSectorWiseData.index = SectorCountry
TotalSectorWiseData.head()
# Out:
#                     AUS(Agricultural)  AUS(Manufacturing)   AUS(Mining)  \
# AUS(Agricultural)         6268.726064         3160.600762     14.661379
# AUS(Manufacturing)       11756.862497        30536.020962  10628.595227
# AUS(Mining)                 28.648618         2753.614407    996.265557
# AUS(Service)                 0.000000            0.000000      0.000000
# AUS(Power)                   6.054712          565.353017    493.079476
#
#                     AUS(Service)   AUS(Power)   AUS(Water)  AUS(Retail)  \
# AUS(Agricultural)            0.0   108.078192   749.453089  1540.247650
# AUS(Manufacturing)           0.0  2714.123166  1341.013513  6163.235749
# AUS(Mining)                  0.0   464.498211  1327.129672   783.149681
# AUS(Service)                 0.0     0.000000     0.000000     0.000000
# AUS(Power)                   0.0  2473.623644  1099.631775   261.046938
#
#                     AUS(Transportation)   AUS(Food)  AUS(Entertainment)  \
# ...
